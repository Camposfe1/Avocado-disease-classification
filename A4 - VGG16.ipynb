# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from pathlib import Path
import keras
from keras import layers
import matplotlib.pyplot as plt
import shutil
import random
import pathlib
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_datos = "/content/drive/MyDrive/Entrenamientos DL COA 690/Nuevos datos/Conjunto Completo.zip"
ruta_salida = "/content/"
# !unzip -qq "{ruta_datos}" -d "{ruta_salida}"

# %%
original_dir = pathlib.Path("/content/Conjunto Completo")
new_base_dir = pathlib.Path("/content/")
classes = ["A", "R", "S"]

train_split = 0.70
val_split = 0.10
test_split = 0.20

for category in classes:
    print(f"Processing {category} images...")

    # Get the filenames for the current category
    fnames = [fname for fname in os.listdir(original_dir) if fname.startswith(category)]

    # Get the total number of images
    n_images = len(fnames)

    # Shuffle the filenames randomly
    np.random.seed(1)
    np.random.shuffle(fnames)

    # Calculate the number of images for each set
    n_train = int(train_split * n_images)
    n_val = int(val_split * n_images)
    n_test = n_images - n_train - n_val

    # Split the filenames into sets
    train_fnames = fnames[:n_train]
    val_fnames = fnames[n_train:n_train+n_val]
    test_fnames = fnames[n_train+n_val:]

    # Create the directories for the sets
    train_dir = new_base_dir / "train" / category
    val_dir = new_base_dir / "validation" / category
    test_dir = new_base_dir / "test" / category

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Copy the images to the corresponding directories
    for fname in train_fnames:
        src_path = original_dir / fname
        dst_path = train_dir / fname
        shutil.copyfile(src_path, dst_path)

    for fname in val_fnames:
        src_path = original_dir / fname
        dst_path = val_dir / fname
        shutil.copyfile(src_path, dst_path)

    for fname in test_fnames:
        src_path = original_dir / fname
        dst_path = test_dir / fname
        shutil.copyfile(src_path, dst_path)

print("Done.")
# Out:
# Processing A images...
# Processing R images...
# Processing S images...
# Done.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(224, 224),
    batch_size=32,
    label_mode = 'categorical')
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(224, 224),
    batch_size=16,
    label_mode = 'categorical')
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(224, 224),
    batch_size=16,
    label_mode = 'categorical',
    shuffle = False)
# Out:
# Found 467 files belonging to 3 classes.
# Found 65 files belonging to 3 classes.
# Found 137 files belonging to 3 classes.

# %%
data_augmentation = keras.Sequential(
        [
            layers.RandomRotation(random.uniform(0, 0.2)),
            layers.RandomZoom(random.uniform(0.1, 0.3)),
            layers.RandomContrast(random.uniform(0.1, 0.3)),
            layers.RandomBrightness(random.uniform(0.1, 0.3)),
            layers.RandomWidth(factor=random.uniform(0.1, 0.3)),
            layers.RandomHeight(factor=random.uniform(0.1, 0.3)),
            layers.RandomCrop(height=200, width=200),
            layers.RandomTranslation(height_factor=random.uniform(0, 0.1),
                                      width_factor=random.uniform(0, 0.1)),
            layers.RandomFlip("horizontal")
        ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
import keras
from tensorflow.keras import layers

conv_base = keras.applications.vgg16.VGG16(
    weights = 'imagenet',
    include_top = False
)

conv_base.trainable = True
for layer in conv_base.layers[-4:]:
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(3, activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 200, 200, 3)       0
#
#  tf.__operators__.getitem (S  (None, 200, 200, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 200, 200, 3)      0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 256)               4718848
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 19,434,307
# Trainable params: 12,354,883
# Non-trainable params: 7,079,424
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = optimizers.Adamax(learning_rate = 0.001),
              metrics = ['accuracy'])

# %%
callbacks = [
    ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor='val_accuracy'
    ),
    EarlyStopping(
        monitor = 'val_accuracy',
        patience = 20
    )
]

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 20s 282ms/step - loss: 9.0572 - accuracy: 0.3169 - val_loss: 1.1472 - val_accuracy: 0.4308
# Epoch 2/100
# 15/15 [==============================] - 1s 57ms/step - loss: 1.3161 - accuracy: 0.3747 - val_loss: 1.1905 - val_accuracy: 0.2615
# Epoch 3/100
# 15/15 [==============================] - 1s 56ms/step - loss: 1.1589 - accuracy: 0.4133 - val_loss: 1.0204 - val_accuracy: 0.3538
# Epoch 4/100
# 15/15 [==============================] - 1s 83ms/step - loss: 1.1125 - accuracy: 0.4561 - val_loss: 0.9561 - val_accuracy: 0.6000
# Epoch 5/100
# 15/15 [==============================] - 1s 56ms/step - loss: 1.0217 - accuracy: 0.5032 - val_loss: 0.9406 - val_accuracy: 0.5846
# Epoch 6/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.9547 - accuracy: 0.5546 - val_loss: 0.8635 - val_accuracy: 0.6154
# Epoch 7/100
# 15/15 [==============================] - 2s 141ms/step - loss: 0.9384 - accuracy: 0.5824 - val_loss: 0.8434 - val_accuracy: 0.6615
# Epoch 8/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.8556 - accuracy: 0.5803 - val_loss: 0.9534 - val_accuracy: 0.6308
# Epoch 9/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.9537 - accuracy: 0.6081 - val_loss: 0.9243 - val_accuracy: 0.6308
# Epoch 10/100
# 15/15 [==============================] - 1s 82ms/step - loss: 0.8766 - accuracy: 0.6103 - val_loss: 0.7805 - val_accuracy: 0.6769
# Epoch 11/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.8773 - accuracy: 0.6231 - val_loss: 0.8215 - val_accuracy: 0.5692
# Epoch 12/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.8425 - accuracy: 0.6360 - val_loss: 0.7259 - val_accuracy: 0.6769
# Epoch 13/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.7780 - accuracy: 0.6510 - val_loss: 0.6911 - val_accuracy: 0.6769
# Epoch 14/100
# 15/15 [==============================] - 1s 82ms/step - loss: 0.7185 - accuracy: 0.6895 - val_loss: 0.6233 - val_accuracy: 0.7077
# Epoch 15/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.7183 - accuracy: 0.7002 - val_loss: 0.5819 - val_accuracy: 0.7231
# Epoch 16/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6395 - accuracy: 0.7238 - val_loss: 0.6734 - val_accuracy: 0.6923
# Epoch 17/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.5765 - accuracy: 0.7323 - val_loss: 0.5587 - val_accuracy: 0.8000
# Epoch 18/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.6132 - accuracy: 0.7495 - val_loss: 0.6139 - val_accuracy: 0.7692
# Epoch 19/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.5989 - accuracy: 0.7345 - val_loss: 0.7859 - val_accuracy: 0.6769
# Epoch 20/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5912 - accuracy: 0.7580 - val_loss: 0.8288 - val_accuracy: 0.6923
# Epoch 21/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6053 - accuracy: 0.7473 - val_loss: 0.6552 - val_accuracy: 0.7385
# Epoch 22/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6224 - accuracy: 0.7473 - val_loss: 1.0319 - val_accuracy: 0.6154
# Epoch 23/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5793 - accuracy: 0.7837 - val_loss: 0.6082 - val_accuracy: 0.7385
# Epoch 24/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6042 - accuracy: 0.7666 - val_loss: 0.7297 - val_accuracy: 0.7077
# Epoch 25/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5676 - accuracy: 0.7602 - val_loss: 0.7579 - val_accuracy: 0.7692
# Epoch 26/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5557 - accuracy: 0.7816 - val_loss: 0.6840 - val_accuracy: 0.7385
# Epoch 27/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.6005 - accuracy: 0.7495 - val_loss: 0.8456 - val_accuracy: 0.7231
# Epoch 28/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6052 - accuracy: 0.7516 - val_loss: 0.5636 - val_accuracy: 0.7538
# Epoch 29/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5051 - accuracy: 0.8116 - val_loss: 0.6516 - val_accuracy: 0.7846
# Epoch 30/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5314 - accuracy: 0.8030 - val_loss: 0.5307 - val_accuracy: 0.7692
# Epoch 31/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.5774 - accuracy: 0.7666 - val_loss: 0.6297 - val_accuracy: 0.7538
# Epoch 32/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.6120 - accuracy: 0.7495 - val_loss: 0.4605 - val_accuracy: 0.8615
# Epoch 33/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4697 - accuracy: 0.8201 - val_loss: 0.7465 - val_accuracy: 0.8000
# Epoch 34/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5851 - accuracy: 0.7516 - val_loss: 0.5025 - val_accuracy: 0.8000
# Epoch 35/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5263 - accuracy: 0.8030 - val_loss: 0.4929 - val_accuracy: 0.8154
# Epoch 36/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4774 - accuracy: 0.8180 - val_loss: 0.5915 - val_accuracy: 0.8000
# Epoch 37/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5158 - accuracy: 0.7966 - val_loss: 0.4994 - val_accuracy: 0.8462
# Epoch 38/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5340 - accuracy: 0.7880 - val_loss: 0.4845 - val_accuracy: 0.8462
# Epoch 39/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4906 - accuracy: 0.8009 - val_loss: 0.6048 - val_accuracy: 0.7385
# Epoch 40/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4896 - accuracy: 0.7987 - val_loss: 0.6014 - val_accuracy: 0.7385
# Epoch 41/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4738 - accuracy: 0.8201 - val_loss: 0.4984 - val_accuracy: 0.8154
# Epoch 42/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5214 - accuracy: 0.8009 - val_loss: 0.4068 - val_accuracy: 0.8615
# Epoch 43/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4721 - accuracy: 0.7987 - val_loss: 0.5327 - val_accuracy: 0.7846
# Epoch 44/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.5104 - accuracy: 0.7923 - val_loss: 0.6619 - val_accuracy: 0.7231
# Epoch 45/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.4578 - accuracy: 0.8201 - val_loss: 0.4474 - val_accuracy: 0.8154
# Epoch 46/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.5293 - accuracy: 0.7923 - val_loss: 0.4758 - val_accuracy: 0.8462
# Epoch 47/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4748 - accuracy: 0.8094 - val_loss: 0.6498 - val_accuracy: 0.7846
# Epoch 48/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.4666 - accuracy: 0.8180 - val_loss: 0.5651 - val_accuracy: 0.8154
# Epoch 49/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.4822 - accuracy: 0.8009 - val_loss: 0.4863 - val_accuracy: 0.8154
# Epoch 50/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.4471 - accuracy: 0.8308 - val_loss: 0.4379 - val_accuracy: 0.8462
# Epoch 51/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4788 - accuracy: 0.8244 - val_loss: 0.5116 - val_accuracy: 0.8000
# Epoch 52/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.4632 - accuracy: 0.8266 - val_loss: 0.4621 - val_accuracy: 0.8462

# %%
best_val_acc = callbacks[0].best
best_epoch = np.argmax(history.history['val_accuracy']) + 1

print("Mejor época: ", best_epoch)
print("Val Acc de la mejor época: {:.2f}".format(best_val_acc))
# Out:
# Mejor época:  32
# Val Acc de la mejor época: 0.86

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
ruta_modelos = "/content/drive/MyDrive/Entrenamientos DL COA 690/Nuevos datos/Modelos optimizados/"
os.chdir(ruta_modelos)
test_model = keras.models.load_model("/content/convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")

test_model.save("VGG16.keras")
# Out:
# 9/9 [==============================] - 1s 56ms/step - loss: 0.7353 - accuracy: 0.7372
# Test accuracy: 0.737

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

test_predictions = test_model.predict(test_dataset)
test_labels = np.concatenate([labels for _, labels in test_dataset], axis=0)
test_labels = np.argmax(test_labels, axis=1)
# Out:
# 9/9 [==============================] - 0s 12ms/step

# %%
# Obtener las clases predichas
predicted_classes = np.argmax(test_predictions, axis=1)

# Generar el informe de clasificación
classification_rep = classification_report(test_labels, predicted_classes)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.70      0.64        37
#            1       0.84      0.66      0.74        41
#            2       0.79      0.81      0.80        59
#
#     accuracy                           0.74       137
#    macro avg       0.74      0.72      0.73       137
# weighted avg       0.75      0.74      0.74       137

# %%
test_accuracy = accuracy_score(test_labels, predicted_classes)

print("Precisión en el conjunto de prueba: {:.2f}%".format(test_accuracy * 100))
# Out:
# Precisión en el conjunto de prueba: 73.72%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay

# Calcula la matriz de confusión
confusion = confusion_matrix(test_labels, predicted_classes, normalize = 'true')

display = ConfusionMatrixDisplay(confusion_matrix = confusion,
                                 display_labels = classes)

fig, ax = plt.subplots()
display.plot(ax=ax)
ax.set_title("Matriz de confusión para A4")
ax.set_xlabel("Valores reales")
ax.set_ylabel("Valores predichos")
plt.show()
