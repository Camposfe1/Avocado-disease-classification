# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
import shutil
import pathlib
from pathlib import Path
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_datos = "/content/drive/MyDrive/Entrenamientos DL COA 690/Nuevos datos/Conjunto Completo.zip"
ruta_salida = "/content/"
# !unzip -qq "{ruta_datos}" -d "{ruta_salida}"

# %%
original_dir = pathlib.Path("/content/Conjunto Completo")
new_base_dir = pathlib.Path("/content/")
classes = ["A", "R", "S"]

train_split = 0.70
val_split = 0.10
test_split = 0.20

for category in classes:
    print(f"Processing {category} images...")
    
    # Get the filenames for the current category
    fnames = [fname for fname in os.listdir(original_dir) if fname.startswith(category)]
    
    # Get the total number of images
    n_images = len(fnames)
    
    # Shuffle the filenames randomly
    np.random_state = 1
    np.random.shuffle(fnames)
    
    # Calculate the number of images for each set
    n_train = int(train_split * n_images)
    n_val = int(val_split * n_images)
    n_test = n_images - n_train - n_val
    
    # Split the filenames into sets
    train_fnames = fnames[:n_train]
    val_fnames = fnames[n_train:n_train+n_val]
    test_fnames = fnames[n_train+n_val:]
    
    # Create the directories for the sets
    train_dir = new_base_dir / "train" / category
    val_dir = new_base_dir / "validation" / category
    test_dir = new_base_dir / "test" / category
    
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)
    
    # Copy the images to the corresponding directories
    for fname in train_fnames:
        src_path = original_dir / fname
        dst_path = train_dir / fname
        shutil.copyfile(src_path, dst_path)
        
    for fname in val_fnames:
        src_path = original_dir / fname
        dst_path = val_dir / fname
        shutil.copyfile(src_path, dst_path)
        
    for fname in test_fnames:
        src_path = original_dir / fname
        dst_path = test_dir / fname
        shutil.copyfile(src_path, dst_path)
    
print("Done.")
# Out:
# Processing A images...
# Processing R images...
# Processing S images...
# Done.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(224, 224),
    batch_size=16,
    label_mode = 'categorical')
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(224, 224),
    batch_size=16,
    label_mode = 'categorical')
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(224, 224),
    batch_size=16,
    label_mode = 'categorical',
    shuffle = False)
# Out:
# Found 467 files belonging to 3 classes.
# Found 65 files belonging to 3 classes.
# Found 137 files belonging to 3 classes.

# %%
data_augmentation = keras.Sequential(
        [
            layers.RandomRotation(random.uniform(0, 0.2)),
            layers.RandomZoom(random.uniform(0.1, 0.3)),
            layers.RandomContrast(random.uniform(0.1, 0.3)),
            layers.RandomBrightness(random.uniform(0.1, 0.3)),
            layers.RandomWidth(factor=random.uniform(0.1, 0.3)),
            layers.RandomHeight(factor=random.uniform(0.1, 0.3)),
            layers.RandomCrop(height=200, width=200),
            layers.RandomTranslation(height_factor=random.uniform(0, 0.1), 
                                      width_factor=random.uniform(0, 0.1)),
            layers.RandomFlip("horizontal"),
            layers.RandomFlip("vertical"),
        ]
)

# %%
for data_batch, labels_batch in train_dataset:
  print("data batch shape:", data_batch.shape)
  print("labels batch shape", labels_batch.shape)
  break
# Out:
# data batch shape: (16, 224, 224, 3)
# labels batch shape (16, 3)

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)

x = layers.Conv2D(filters=8, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)

x = layers.Dense(128, activation = 'relu')(x)

x = layers.Dense(32, activation = 'relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(3, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 200, 200, 3)       0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 198, 198, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 196,883
# Trainable params: 196,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = optimizers.RMSprop(learning_rate = 0.001),
              metrics = ['accuracy'])

# %%
callbacks = [
    ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor='val_accuracy'
    ),
    EarlyStopping(
        monitor = 'val_accuracy',
        patience = 20
    )
]

history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 15s 38ms/step - loss: 1.1027 - accuracy: 0.4090 - val_loss: 1.0762 - val_accuracy: 0.4308
# Epoch 2/100
# 30/30 [==============================] - 0s 14ms/step - loss: 1.0934 - accuracy: 0.4026 - val_loss: 1.0907 - val_accuracy: 0.4308
# Epoch 3/100
# 30/30 [==============================] - 0s 14ms/step - loss: 1.0900 - accuracy: 0.4261 - val_loss: 1.0715 - val_accuracy: 0.4308
# Epoch 4/100
# 30/30 [==============================] - 0s 14ms/step - loss: 1.0816 - accuracy: 0.4261 - val_loss: 1.0797 - val_accuracy: 0.4308
# Epoch 5/100
# 30/30 [==============================] - 0s 14ms/step - loss: 1.0727 - accuracy: 0.4497 - val_loss: 1.0560 - val_accuracy: 0.4308
# Epoch 6/100
# 30/30 [==============================] - 0s 14ms/step - loss: 1.0622 - accuracy: 0.4711 - val_loss: 1.0932 - val_accuracy: 0.3077
# Epoch 7/100
# 30/30 [==============================] - 1s 16ms/step - loss: 1.0528 - accuracy: 0.4861 - val_loss: 1.0050 - val_accuracy: 0.5231
# Epoch 8/100
# 30/30 [==============================] - 1s 16ms/step - loss: 1.0448 - accuracy: 0.4989 - val_loss: 0.9407 - val_accuracy: 0.5538
# Epoch 9/100
# 30/30 [==============================] - 1s 16ms/step - loss: 1.0171 - accuracy: 0.5439 - val_loss: 0.9368 - val_accuracy: 0.6000
# Epoch 10/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.9844 - accuracy: 0.5567 - val_loss: 0.9267 - val_accuracy: 0.6154
# Epoch 11/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.9356 - accuracy: 0.5760 - val_loss: 0.8101 - val_accuracy: 0.6308
# Epoch 12/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.9213 - accuracy: 0.5632 - val_loss: 1.4049 - val_accuracy: 0.3538
# Epoch 13/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8831 - accuracy: 0.6039 - val_loss: 1.1137 - val_accuracy: 0.4154
# Epoch 14/100
# 30/30 [==============================] - 1s 15ms/step - loss: 0.8450 - accuracy: 0.6167 - val_loss: 0.7730 - val_accuracy: 0.6615
# Epoch 15/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8777 - accuracy: 0.5867 - val_loss: 0.8159 - val_accuracy: 0.6615
# Epoch 16/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.8576 - accuracy: 0.6253 - val_loss: 0.7592 - val_accuracy: 0.6308
# Epoch 17/100
# 30/30 [==============================] - 1s 15ms/step - loss: 0.8398 - accuracy: 0.6210 - val_loss: 0.7882 - val_accuracy: 0.6769
# Epoch 18/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8753 - accuracy: 0.6124 - val_loss: 0.7563 - val_accuracy: 0.6615
# Epoch 19/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7944 - accuracy: 0.6360 - val_loss: 1.3298 - val_accuracy: 0.5231
# Epoch 20/100
# 30/30 [==============================] - 1s 15ms/step - loss: 0.8315 - accuracy: 0.6060 - val_loss: 0.8088 - val_accuracy: 0.7077
# Epoch 21/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8123 - accuracy: 0.6660 - val_loss: 0.8481 - val_accuracy: 0.6462
# Epoch 22/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7678 - accuracy: 0.6574 - val_loss: 0.9569 - val_accuracy: 0.4308
# Epoch 23/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8122 - accuracy: 0.6574 - val_loss: 0.7657 - val_accuracy: 0.6308
# Epoch 24/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7927 - accuracy: 0.6681 - val_loss: 0.7090 - val_accuracy: 0.6615
# Epoch 25/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8107 - accuracy: 0.6638 - val_loss: 0.7397 - val_accuracy: 0.6923
# Epoch 26/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.8096 - accuracy: 0.6445 - val_loss: 0.7107 - val_accuracy: 0.7231
# Epoch 27/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7861 - accuracy: 0.6681 - val_loss: 0.8129 - val_accuracy: 0.6308
# Epoch 28/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7752 - accuracy: 0.6702 - val_loss: 0.7960 - val_accuracy: 0.6308
# Epoch 29/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7639 - accuracy: 0.6574 - val_loss: 0.9246 - val_accuracy: 0.6308
# Epoch 30/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7055 - accuracy: 0.7024 - val_loss: 1.5459 - val_accuracy: 0.3846
# Epoch 31/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7651 - accuracy: 0.6874 - val_loss: 0.6954 - val_accuracy: 0.7231
# Epoch 32/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7435 - accuracy: 0.6981 - val_loss: 0.8143 - val_accuracy: 0.6000
# Epoch 33/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7163 - accuracy: 0.7131 - val_loss: 0.6822 - val_accuracy: 0.7231
# Epoch 34/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7076 - accuracy: 0.7259 - val_loss: 0.6308 - val_accuracy: 0.6923
# Epoch 35/100
# 30/30 [==============================] - 1s 16ms/step - loss: 0.6978 - accuracy: 0.7366 - val_loss: 0.5675 - val_accuracy: 0.7846
# Epoch 36/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6889 - accuracy: 0.7323 - val_loss: 0.8740 - val_accuracy: 0.6154
# Epoch 37/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6791 - accuracy: 0.6938 - val_loss: 0.7066 - val_accuracy: 0.6923
# Epoch 38/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.7022 - accuracy: 0.7238 - val_loss: 0.6668 - val_accuracy: 0.7231
# Epoch 39/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7075 - accuracy: 0.7216 - val_loss: 0.6077 - val_accuracy: 0.7538
# Epoch 40/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6952 - accuracy: 0.7109 - val_loss: 0.8083 - val_accuracy: 0.5692
# Epoch 41/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.6886 - accuracy: 0.7045 - val_loss: 0.5465 - val_accuracy: 0.8000
# Epoch 42/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7044 - accuracy: 0.7452 - val_loss: 0.6842 - val_accuracy: 0.6615
# Epoch 43/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7062 - accuracy: 0.7281 - val_loss: 0.6162 - val_accuracy: 0.7538
# Epoch 44/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6726 - accuracy: 0.7323 - val_loss: 0.5945 - val_accuracy: 0.7077
# Epoch 45/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6789 - accuracy: 0.7452 - val_loss: 0.6368 - val_accuracy: 0.7231
# Epoch 46/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6541 - accuracy: 0.7430 - val_loss: 0.7240 - val_accuracy: 0.6923
# Epoch 47/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6463 - accuracy: 0.7388 - val_loss: 0.5290 - val_accuracy: 0.7385
# Epoch 48/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6011 - accuracy: 0.7709 - val_loss: 0.4937 - val_accuracy: 0.7692
# Epoch 49/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6503 - accuracy: 0.7495 - val_loss: 0.7828 - val_accuracy: 0.5846
# Epoch 50/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6594 - accuracy: 0.7259 - val_loss: 0.5270 - val_accuracy: 0.7538
# Epoch 51/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6454 - accuracy: 0.7859 - val_loss: 0.5855 - val_accuracy: 0.7385
# Epoch 52/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6351 - accuracy: 0.7559 - val_loss: 0.9672 - val_accuracy: 0.6615
# Epoch 53/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6573 - accuracy: 0.7537 - val_loss: 0.4752 - val_accuracy: 0.7846
# Epoch 54/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6385 - accuracy: 0.7623 - val_loss: 0.5915 - val_accuracy: 0.7385
# Epoch 55/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5984 - accuracy: 0.7687 - val_loss: 0.4968 - val_accuracy: 0.8154
# Epoch 56/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6722 - accuracy: 0.7623 - val_loss: 0.5230 - val_accuracy: 0.8154
# Epoch 57/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5731 - accuracy: 0.7516 - val_loss: 0.5414 - val_accuracy: 0.7538
# Epoch 58/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6195 - accuracy: 0.7409 - val_loss: 0.5919 - val_accuracy: 0.7385
# Epoch 59/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5955 - accuracy: 0.7473 - val_loss: 0.7135 - val_accuracy: 0.7077
# Epoch 60/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5993 - accuracy: 0.7602 - val_loss: 0.4906 - val_accuracy: 0.7846
# Epoch 61/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5629 - accuracy: 0.7623 - val_loss: 0.7370 - val_accuracy: 0.6615
# Epoch 62/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5683 - accuracy: 0.7816 - val_loss: 0.9721 - val_accuracy: 0.4923
# Epoch 63/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5919 - accuracy: 0.7666 - val_loss: 0.6243 - val_accuracy: 0.6923
# Epoch 64/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6415 - accuracy: 0.7666 - val_loss: 0.5675 - val_accuracy: 0.7385
# Epoch 65/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5889 - accuracy: 0.7602 - val_loss: 0.5171 - val_accuracy: 0.8154
# Epoch 66/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5603 - accuracy: 0.7580 - val_loss: 0.5923 - val_accuracy: 0.8154
# Epoch 67/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6038 - accuracy: 0.7580 - val_loss: 0.5015 - val_accuracy: 0.7538
# Epoch 68/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.6341 - accuracy: 0.7430 - val_loss: 0.6902 - val_accuracy: 0.6769
# Epoch 69/100
# 30/30 [==============================] - 1s 15ms/step - loss: 0.5783 - accuracy: 0.7880 - val_loss: 0.4873 - val_accuracy: 0.8462
# Epoch 70/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5834 - accuracy: 0.8073 - val_loss: 0.4836 - val_accuracy: 0.8308
# Epoch 71/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5554 - accuracy: 0.7880 - val_loss: 0.4780 - val_accuracy: 0.7846
# Epoch 72/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6011 - accuracy: 0.7837 - val_loss: 0.8220 - val_accuracy: 0.5385
# Epoch 73/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5495 - accuracy: 0.7944 - val_loss: 0.4872 - val_accuracy: 0.8000
# Epoch 74/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5465 - accuracy: 0.7923 - val_loss: 0.4698 - val_accuracy: 0.7846
# Epoch 75/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5131 - accuracy: 0.8073 - val_loss: 0.4343 - val_accuracy: 0.8308
# Epoch 76/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5563 - accuracy: 0.7966 - val_loss: 0.6260 - val_accuracy: 0.7692
# Epoch 77/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5582 - accuracy: 0.8030 - val_loss: 0.4580 - val_accuracy: 0.8000
# Epoch 78/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5108 - accuracy: 0.8201 - val_loss: 0.7361 - val_accuracy: 0.6923
# Epoch 79/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5830 - accuracy: 0.7837 - val_loss: 0.5853 - val_accuracy: 0.7692
# Epoch 80/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5455 - accuracy: 0.7944 - val_loss: 0.6215 - val_accuracy: 0.7846
# Epoch 81/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5147 - accuracy: 0.8180 - val_loss: 0.5452 - val_accuracy: 0.8000
# Epoch 82/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5418 - accuracy: 0.8009 - val_loss: 0.4728 - val_accuracy: 0.8308
# Epoch 83/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5514 - accuracy: 0.7923 - val_loss: 0.5132 - val_accuracy: 0.7538
# Epoch 84/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5321 - accuracy: 0.8009 - val_loss: 0.4790 - val_accuracy: 0.8462
# Epoch 85/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5602 - accuracy: 0.7944 - val_loss: 0.3844 - val_accuracy: 0.8615
# Epoch 86/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5664 - accuracy: 0.7901 - val_loss: 0.4326 - val_accuracy: 0.8154
# Epoch 87/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5300 - accuracy: 0.7816 - val_loss: 0.9694 - val_accuracy: 0.6769
# Epoch 88/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5299 - accuracy: 0.8073 - val_loss: 0.4541 - val_accuracy: 0.8000
# Epoch 89/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5265 - accuracy: 0.7987 - val_loss: 0.3898 - val_accuracy: 0.8154
# Epoch 90/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5521 - accuracy: 0.8073 - val_loss: 0.4808 - val_accuracy: 0.7692
# Epoch 91/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5148 - accuracy: 0.8116 - val_loss: 0.4975 - val_accuracy: 0.8308
# Epoch 92/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5003 - accuracy: 0.8094 - val_loss: 0.5370 - val_accuracy: 0.7846
# Epoch 93/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5210 - accuracy: 0.8137 - val_loss: 0.7066 - val_accuracy: 0.7385
# Epoch 94/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5444 - accuracy: 0.7880 - val_loss: 0.4737 - val_accuracy: 0.8308
# Epoch 95/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.5194 - accuracy: 0.7837 - val_loss: 0.5044 - val_accuracy: 0.7538
# Epoch 96/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.4963 - accuracy: 0.8094 - val_loss: 0.6100 - val_accuracy: 0.7692
# Epoch 97/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4658 - accuracy: 0.8073 - val_loss: 0.5684 - val_accuracy: 0.7538
# Epoch 98/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.5509 - accuracy: 0.7816 - val_loss: 0.4162 - val_accuracy: 0.8769
# Epoch 99/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4878 - accuracy: 0.8180 - val_loss: 0.5144 - val_accuracy: 0.8000
# Epoch 100/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5073 - accuracy: 0.8137 - val_loss: 0.5453 - val_accuracy: 0.7846

# %%
best_val_acc = callbacks[0].best
best_epoch = np.argmax(history.history['val_accuracy']) + 1

print("Mejor época: ", best_epoch)
print("Val Acc de la mejor época: {:.2f}".format(best_val_acc))
# Out:
# Mejor época:  98
# Val Acc de la mejor época: 0.88

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
ruta_modelos = "/content/drive/MyDrive/Entrenamientos DL COA 690/Nuevos datos/Modelos optimizados/"
os.chdir(ruta_modelos)
test_model = keras.models.load_model("Modelo Control.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 9/9 [==============================] - 8s 19ms/step - loss: 0.4362 - accuracy: 0.8759
# Test accuracy: 0.876

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

test_predictions = test_model.predict(test_dataset)
test_labels = np.concatenate([labels for _, labels in test_dataset], axis=0)
test_labels = np.argmax(test_labels, axis=1)
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
classes = ["A", "R", "S"]

# Obtener las clases predichas
predicted_classes = np.argmax(test_predictions, axis=1)

# Generar el informe de clasificación
classification_rep = classification_report(test_labels, predicted_classes, target_names = classes)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            A       0.79      0.89      0.84        37
#            R       0.93      0.93      0.93        41
#            S       0.91      0.83      0.87        59
#
#     accuracy                           0.88       137
#    macro avg       0.87      0.88      0.88       137
# weighted avg       0.88      0.88      0.88       137

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay

# Calcula la matriz de confusión
confusion = confusion_matrix(test_labels, predicted_classes, normalize = 'true')

display = ConfusionMatrixDisplay(confusion_matrix = confusion,
                                 display_labels = classes)

fig, ax = plt.subplots()
display.plot(ax=ax)
ax.set_title("Matriz de confusión para A1")
ax.set_xlabel("Valores reales")
ax.set_ylabel("Valores predichos")
plt.show()
